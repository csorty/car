# %% [markdown]
# <a href="https://colab.research.google.com/github/csorty/car/blob/main/gubv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
from numpy.matrixlib.defmatrix import mat
from numpy import matrix
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from numpy import np


def main():
  x, y = load_iris(return_X_y=True)

  kmeans = KMeans(n_clusters=3)
  kmeans.fit(x)
  labels = kmeans.labels_

  matrix = np.zeros((3, 3))
  for k in range(len(x)):
    for i in range(3):
      for j in range(3):
        if y[k] == i and labels[k] == j:
          matrix[i][j] +=1

  print(matrix)
  result = 0
  for i in range(3):
    result += matrix[i].max()
  print(result/150)

  """
  for real in range(3):
    for pred in range(3):
      cnt = 0
      for i in range(len(y)):
        if y[i] == real and labels[i] == pred:
          cnt += 1
      print(real, pred, cnt)   """


if __name__ == '__main__':
  main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_539/3974240029.py in <cell line: 0>()
#       1 # @title
# ----> 2 from numpy.matrixlib.defmatrix import mat
#       3 from numpy import matrix
#       4 from sklearn.datasets import load_iris
#       5 from sklearn.cluster import KMeans
#
# ImportError: cannot import name 'mat' from 'numpy.matrixlib.defmatrix' (/usr/local/lib/python3.12/dist-packages/numpy/matrixlib/defmatrix.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
