# %% [markdown]
# <a href="https://colab.research.google.com/github/csorty/car/blob/main/photo_music.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
import numpy
import librosa
import matplotlib.pyplot as plt

# A прозрачность

def main():
  img = Image.open("img.webp")
  img = np.array(img)
  print(img)

  path = "music.mp3"
  audio = librosa.load(path)
  print(audio)

  path = "i.jpeg"
  y, cr = librosa.load(path, sr = 22050)
  y = y[:10]
  librosa.display.waveshow(y) #точки соединяет
  plt.plot(range(len(y)), y)
  plt.show


if __name__ == '__main__':
  main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_321/2866920954.py in <cell line: 0>()
#      25
#      26 if __name__ == '__main__':
# ---> 27   main()
#      28
#
# /tmp/ipykernel_321/2866920954.py in main()
#       8
#       9 def main():
# ---> 10   img = Image.open("img.webp")
#      11   img = np.array(img)
#      12   print(img)
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img.webp'

# %%
from PIL import Image
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

def main():
    iris = load_iris() #цветы ириса фишера setosa', 'versicolor', 'virginica обозначают цвета
    print(iris)  #ирис создает готовый датасет, чтобы иметь готовую базу

    # path = "C:\\Users\\Lenovo\\Downloads\\mus.wav"  # записываем название файла
    # y, sr = librosa.load(path,sr = 10)  # считывает файл в переменную аудио # если так две переменные напишем, то в разные переменные напишем частоты и размер автоматически
    # print(y.shape)
    # #y = y[:10]   #срез первых 10 чисел частоты
    # #plt.plot(range(len(y)), y)  # для графика песни
    # librosa.display.waveshow(y)
    # plt.show()

    # print(y)      #выведет каждое число это частота герц, то есть высота столбиков
    # print(y.shape)          #выводит размерность нашего массива

    # пытаемся перевести картинку в код цвета
    # img = Image.open("C:\\Users\\Lenovo\\Pictures\\фоны\\олаф2.jpg")
    # img = np.array(img)   #переводит картинку в массив
    # print(img)

    # картинка пнг будет отличаться от джипег потому что в пнг есть прозрачный фон
    # если бы вставили пнг, то в матрице было бы по 4 числа

if __'main'__ == '__main__':
    main()
